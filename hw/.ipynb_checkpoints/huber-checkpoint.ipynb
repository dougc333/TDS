# %%
n = 30
x = random(n)
y = linear_function(alpha_true,beta_true,x)+0.2*randn(n)
print(x.shape,y.shape)
def square_function_outlier(gamma, beta, alpha,x):
    return square_function(gamma_true,beta_true,alpha_true,x)+0.2*randn(n) + 4*binomial(1, 0.03, size=n) + 4*binomial(1,0.01,size=n)

n = 300
x = random(n)
y = square_function_outlier(gamma_true,beta_true,alpha_true,x)
print(x.shape,y.shape)

z = square_function(gamma_true,beta_true,alpha_true,x)+0.2*randn(n)
print(z.shape)
# Out:
# (30,) (30,)
# (300,) (300,)
# (300,)

# %%
def linear_function(alpha,beta,x): return alpha+beta*x
rc('animation',html='html5')
rcParams['figure.figsize'] = 3, 3

beta_true = 6.0
alpha_true = 3.0
n = 30
x = random(n)
y = linear_function(alpha_true,beta_true,x)+0.2*randn(n)
beta = -1.
alpha = 3.
learning_rate = 0.01

# %%
def update_alpha_and_beta():
    global alpha, beta
    y_predicted = linear_function(alpha,beta,x)
    derivative_of_loss_wrt_alpha = 2*(y_predicted-y)
    derivative_of_loss_wrt_beta = x* derivative_of_loss_wrt_alpha
    alpha = alpha - learning_rate*derivative_of_loss_wrt_alpha.mean()
    beta = beta - learning_rate*derivative_of_loss_wrt_beta.mean()
# i is the frame nuber!
#https://math.unice.fr/~hheumann/Tutorial/_build/intro_matplotlib.html
def animate(i):
    x = np.linspace(0,1,100)
    y = linear_function(alpha,beta,x)
    line.set_data(x,y)
    for i in range(20): 
        update_alpha_and_beta()
    return (line,)

# %%
fig = plt.figure(dpi=80,figsize=(7,7))
ax = fig.add_subplot(111)
ax.set_xlim((0,1))
ax.set_ylim((-2,15))
plt.scatter(x,y)
line, = ax.plot([],[],lw=2)

# %%
resulting_animation = animation.FuncAnimation(fig,animate,frames=np.arange(0,250),interval=100)

# %%
resulting_animation
# Out:
# <video width="560" height="560" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# Notebook adapted from Jeremy P. Howard and Michal Fabinger

# %%
import numpy as np
from numpy.random import random, randn,binomial
from matplotlib import pyplot as plt, animation, rcParams, rc
import math

# %% [markdown]
# $y=\gamma x^2 + \beta x + \alpha$
# <p></p>
#
# <img src="files/huber1.png" />
# Change notation from y to y-hat and f(x) to y.
# $\cfrac{\partial L(theta, y)}{\partial (dependentvars)}=0$
# <p>For x inside quadratic area</p>
# $\cfrac{\partial(loss)}{\partial \gamma}=2x^2(\hat y-y)$
# $\cfrac{\partial(loss)}{\partial \beta}=2x(\hat y -y)$
# $\cfrac{\partial(loss)}{\partial \alpha}=2(\hat y-y)$
# <p>for x outside quadratic area</p>
# $\cfrac{\partial(|loss|- .5*\delta^2)}{\partial \gamma}= \cfrac{loss}{|loss|} \cfrac{\partial (loss)}{\partial \gamma} =
# \cfrac{loss}{|loss|} x^2 $
# <p></p>
# $\cfrac{\partial(loss - .5*\delta^2)}{\partial \beta} = \cfrac{loss}{|loss|} \cfrac{\partial (loss)}{\partial \beta}=
# \cfrac{loss}{|loss|} x$
# <p></p>
# $\cfrac{\partial(loss.5*\delta^2)}{\partial \alpha}=\cfrac{loss}{|loss|} \cfrac{\partial (loss)}{\partial \alpha} =
# \cfrac{loss}{|loss|} 1$
# <p></p>
# $\cfrac{\partial (| \hat y - \gamma x^2 + \beta x + alpha|) }{\partial \gamma} = x^2$
# <p></p>
# $\cfrac{\partial (| \hat y - \gamma x^2 + \beta x + alpha|) }{\partial \beta} = x$
# <p></p>
# $\cfrac{\partial (| \hat y - \gamma x^2 + \beta x + alpha|) }{\partial \alpha} =1 $
# <p></p>

# %% [markdown]
# <h6>Squared Function</h6>

# %%
#It doesnt make sense to use a quadratic to approximate a linear function,so change the dataset to 
#be quadratic


def square_function_outlier(gamma, beta, alpha,x):
    return square_function(gamma_true,beta_true,alpha_true,x)+0.2*randn(n) + 4*binomial(1, 0.03, size=n) + 4*binomial(1,0.01,size=n)

def loss(y,y_pred):
    return y-y_pred
def loss_abs(y,y_pred):
    return math.abs(loss(y,y_pred))

beta_true = 2.0
alpha_true = 2.0
gamma_true = 10.0
delta = .5
n = 300
x = random(n)
y = square_function_outlier(gamma_true,beta_true,alpha_true,x)

beta = -1.
alpha = 3.
gamma = 2.
learning_rate = 0.01

# %%
def is_outlier(x,y):
    #print(x[i],y[i])
    if(0<x and x<0.2 and y>5):
        #print("1:",x[i],y[i])
        return True
    elif(0.2<x and x<0.4 and y>6):
        #print("2:",x[i],y[i])
        #plt.scatter(x[i],y[i],color="red")
        return True
    elif(0.4<x and x<0.6 and y>8):
        #print("3:",x[i],y[i])
        return True
    elif(0.6<x and x<0.8 and y>10.5):
        #print("4:",x[i],y[i])
        return True
    elif(0.8<x and x<0.9 and y>13):
        return True
    elif(0.9<x and x<1.0 and y>15):
        #print("5:",x[i],y[i])
        return True
    else:
        return False


            
fig = plt.figure(dpi=80,figsize=(7,7))

ax = fig.add_subplot(111)
ax.set_xlim((0,1))
ax.set_ylim((-2,15))
for i in range(len(x)):
    if is_outlier(x[i],y[i]):
        plt.scatter(x[i],y[i],color="red")
    else:
        plt.scatter(x[i],y[i],color="blue")
print(len(y))
# Out:
# 300

# %% [markdown]
# <h6>LR fit </h6>

# %%
def update_squared():
    global gamma, alpha, beta
    y_predicted = square_function(gamma,beta,alpha,x)
    #messed up you have to iterate through each traning example
    der_wrt_gamma = 2*(x**2)*(y_predicted-y)
    der_wrt_alpha = 2*(y_predicted-y)
    der_wrt_beta =  x*der_wrt_alpha
    alpha = alpha - learning_rate*der_wrt_alpha.mean()
    beta = beta - learning_rate*der_wrt_beta.mean()
    gamma = gamma - learning_rate * der_wrt_gamma.mean()
    
def animate(i):
    x = np.linspace(0,1,100)
    y = square_function_outlier(gamma,beta,alpha,x)
    line.set_data(x,y)
    for i in range(20): 
        update_squared()
    return (line,)

# %%
fig = plt.figure(dpi=80,figsize=(7,7))
ax = fig.add_subplot(111)
ax.set_xlim((0,1))
ax.set_ylim((-2,15))
plt.scatter(x,y)
line, = ax.plot([],[],lw=2)

# %%
resulting_animation = animation.FuncAnimation(fig,animate,frames=np.arange(0,250),interval=100)

# %%
resulting_animation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/envs/TDS/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1400         fmt = rcParams['animation.html']
#    1401         if fmt == 'html5':
# -> 1402             return self.to_html5_video()
#    1403         elif fmt == 'jshtml':
#    1404             return self.to_jshtml()
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1341                                 bitrate=rcParams['animation.bitrate'],
#    1342                                 fps=1000. / self._interval)
# -> 1343                 self.save(str(path), writer=writer)
#    1344                 # Now open and base64 encode.
#    1345                 vid64 = base64.encodebytes(path.read_bytes())
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1167                 for anim in all_anim:
#    1168                     # Clear the initial frame
# -> 1169                     anim._init_draw()
#    1170                 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1171                     for anim, d in zip(all_anim, data):
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in _init_draw(self)
#    1738         # artists.
#    1739         if self._init_func is None:
# -> 1740             self._draw_frame(next(self.new_frame_seq()))
#    1741
#    1742         else:
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1760         # Call the func with framedata and args. If blitting is desired,
#    1761         # func needs to return a sequence of any artists that were modified.
# -> 1762         self._drawn_artists = self._func(framedata, *self._args)
#    1763         if self._blit:
#    1764             if self._drawn_artists is None:
#
# <ipython-input-45-bdb7f514594e> in animate(i)
#      12 def animate(i):
#      13     x = np.linspace(0,1,100)
# ---> 14     y = square_function_outlier(gamma,beta,alpha,x)
#      15     line.set_data(x,y)
#      16     for i in range(20):
#
# <ipython-input-43-1c2248cfed32> in square_function_outlier(gamma, beta, alpha, x)
#       4
#       5 def square_function_outlier(gamma, beta, alpha,x):
# ----> 6     return square_function(gamma_true,beta_true,alpha_true,x)+0.2*randn(n) + 4*binomial(1, 0.03, size=n) + 4*binomial(1,0.01,size=n)
#       7
#       8 def loss(y,y_pred):
#
# ValueError: operands could not be broadcast together with shapes (100,) (300,)

# %%
def update_squared(delta):
    global gamma, alpha, beta
    y_predicted = square_function(gamma,beta,alpha,x)
    #messed up you have to iterate through each traning example
    for i in range(n):
        #print("x:",x[i]," y[i]",y[i])
        if math.abs(y[i]-y_predicted) < delta:
            der_wrt_gamma = (2/n)*(x[i]**2)*(y_predicted-y[i])
            der_wrt_alpha = (2/n)*(y_predicted-y[i])
            der_wrt_beta = (x[i]/n)*der_wrt_alpha
        else:
            der_wrt_gamma = (1/n)*(x[i]**2)*loss/loss_abs
            der_wrt_alpha = (1/n)*x[i]*loss/loss_abs
            der_wrt_beta = (1/n)*1 * loss/loss_abs
        alpha = alpha - learning_rate*der_wrt_alpha
        beta = beta - learning_rate*der_wrt_beta
        gamma = gamma - learning_rate * der_wrt_gamma
    
def animate(i):
    x = np.linspace(0,1,100)
    y = square_function(gamma,beta,alpha,x)
    line.set_data(x,y)
    for i in range(20): 
        update_squared(.1)
    return (line,)

# %%
#what is outlier supposed to do? does it become linear vs. squared loss? 



for i in range(2): 
    update_squared()

# %%
fig = plt.figure(dpi=80,figsize=(7,7))
ax = fig.add_subplot(111)
ax.set_xlim((0,1))
ax.set_ylim((-2,15))
plt.scatter(x,y)
line, = ax.plot([],[],lw=2)

# %%
resulting_animation = animation.FuncAnimation(fig,animate,frames=np.arange(0,250),interval=100)

# %%
resulting_animation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/envs/TDS/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1400         fmt = rcParams['animation.html']
#    1401         if fmt == 'html5':
# -> 1402             return self.to_html5_video()
#    1403         elif fmt == 'jshtml':
#    1404             return self.to_jshtml()
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1341                                 bitrate=rcParams['animation.bitrate'],
#    1342                                 fps=1000. / self._interval)
# -> 1343                 self.save(str(path), writer=writer)
#    1344                 # Now open and base64 encode.
#    1345                 vid64 = base64.encodebytes(path.read_bytes())
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1167                 for anim in all_anim:
#    1168                     # Clear the initial frame
# -> 1169                     anim._init_draw()
#    1170                 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1171                     for anim, d in zip(all_anim, data):
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in _init_draw(self)
#    1738         # artists.
#    1739         if self._init_func is None:
# -> 1740             self._draw_frame(next(self.new_frame_seq()))
#    1741
#    1742         else:
#
# /anaconda3/envs/TDS/lib/python3.7/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1760         # Call the func with framedata and args. If blitting is desired,
#    1761         # func needs to return a sequence of any artists that were modified.
# -> 1762         self._drawn_artists = self._func(framedata, *self._args)
#    1763         if self._blit:
#    1764             if self._drawn_artists is None:
#
# <ipython-input-37-40ea3ff2cc46> in animate(i)
#      19 def animate(i):
#      20     x = np.linspace(0,1,100)
# ---> 21     y = square_function(gamma,beta,alpha,x)
#      22     line.set_data(x,y)
#      23     for i in range(20):
#
# <ipython-input-21-8b04dc29f24a> in square_function(gamma, beta, alpha, x)
#       7
#       8 def square_function(gamma, beta, alpha,x):
# ----> 9     return gamma*x**2 + beta*x + alpha
#      10
#      11 beta_true = 2.0
#
# ValueError: operands could not be broadcast together with shapes (300,) (100,)

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=30, metadata=dict(artist='Me'), bitrate=1800)
resulting_animation.save('files/huber_animation.mp4', writer=writer)
