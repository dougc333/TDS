# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

img = cv2.imread('train-labels.tif',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.show()

# %%
img = cv2.imread('train-volume.tif',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.show()

# %%
img = cv2.imread('test-volume.tif',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.show()
