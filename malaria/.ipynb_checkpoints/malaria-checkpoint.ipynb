# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

big=True

img = cv2.imread("/images/41be1bd3-0d31-4881-bf1f-3ccdfa21ff12.jpg")
print(type(img))
print(img.shape)
if (big):
    cv2.circle(img,(576,1744), 55, (0,255,0), -1)
    #cv2.circle(img,(576,1744), 55, (0,255,0), -1)
    cv2.imshow('image',img)
    
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    plt.imshow(img)
    plt.show()
# Out:
# <class 'NoneType'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-aee80990a108> in <module>
#       7 img = cv2.imread("/images/41be1bd3-0d31-4881-bf1f-3ccdfa21ff12.jpg")
#       8 print(type(img))
# ----> 9 print(img.shape)
#      10 if (big):
#      11     cv2.circle(img,(576,1744), 55, (0,255,0), -1)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import json

test = json.load(open("test.json","r"))
train = json.load(open("training.json","r"))
print("num test:",len(test))
print("num train:",len(train))
num_test=0
num_train=0

for x in test:
    print(x['image']['pathname'])
    try:
        fh = open(x['image']['pathname'])
        num_test +=1
    except:
        print("nto found")
for x in train:
    print(x['image']['pathname'])
    try:
        fh = open(x['image']['pathname'])
        num_train +=1
    except:
        print("nto found")
print(num_test,num_train)
# Out:
# num test: 120
# num train: 1208
# /images/41be1bd3-0d31-4881-bf1f-3ccdfa21ff12.jpg
# nto found
# /images/64985a1e-16bb-4016-a01c-c21a5b86e572.jpg
# nto found
# /images/c70894fa-50e8-4eed-a5a8-159a20153a49.jpg
# nto found
# /images/abb72ce2-4193-4dd3-a34c-61c2ee22ccff.jpg
# nto found
# /images/8db76867-671a-4488-a7b6-991e4dd2e05f.jpg
# nto found
# /images/ebc4056e-d766-43cf-b6b4-5dac79d96e84.jpg
# nto found
# /images/d9ecacb0-14c7-4862-930b-18bb51d5f392.jpg
# nto found
# /images/96287315-87a1-4045-9e16-119e045bf12a.jpg
# nto found
# /images/37df4ffb-f268-4557-94d6-bf68d005feae.jpg
# nto found
# /images/8298aca0-5099-4d45-88ca-ec8ac7922e77.jpg
# nto found
# /images/a612e0d5-6a95-43cc-96a6-6fbcb8d45ff4.jpg
# nto found
# /images/a6e72060-5bde-490c-bdd7-7d9cb0fce7fc.jpg
# nto found
# /images/c11081a1-4fd9-4003-8bd9-0727eae62d0a.jpg
# nto found
# /images/738b7be5-59b5-4d8c-8769-cbf2385b9fc7.jpg
# nto found
# /images/51c6bc6b-4f37-4ce3-b624-840b27c1584a.jpg
# nto found
# ...

# %%
for x in test[0]['objects']:
    print(x['bounding_box'])
    print(x['bounding_box']['minimum'], x['bounding_box']['maximum'])
    print(x['bounding_box']['minimum']['r'],x['bounding_box']['minimum']['c'],x['bounding_box']['maximum']['r'] ,x['bounding_box']['maximum']['c'])
# Out:
# {'minimum': {'r': 576, 'c': 1744}, 'maximum': {'r': 708, 'c': 1883}}
# {'r': 576, 'c': 1744} {'r': 708, 'c': 1883}
# 576 1744 708 1883
# {'minimum': {'r': 863, 'c': 1249}, 'maximum': {'r': 977, 'c': 1373}}
# {'r': 863, 'c': 1249} {'r': 977, 'c': 1373}
# 863 1249 977 1373
# {'minimum': {'r': 210, 'c': 1573}, 'maximum': {'r': 335, 'c': 1711}}
# {'r': 210, 'c': 1573} {'r': 335, 'c': 1711}
# 210 1573 335 1711
# {'minimum': {'r': 1017, 'c': 1124}, 'maximum': {'r': 1142, 'c': 1253}}
# {'r': 1017, 'c': 1124} {'r': 1142, 'c': 1253}
# 1017 1124 1142 1253
# {'minimum': {'r': 572, 'c': 1655}, 'maximum': {'r': 695, 'c': 1763}}
# {'r': 572, 'c': 1655} {'r': 695, 'c': 1763}
# 572 1655 695 1763
# {'minimum': {'r': 477, 'c': 1307}, 'maximum': {'r': 590, 'c': 1429}}
# {'r': 477, 'c': 1307} {'r': 590, 'c': 1429}
# 477 1307 590 1429
# {'minimum': {'r': 962, 'c': 595}, 'maximum': {'r': 1089, 'c': 738}}
# {'r': 962, 'c': 595} {'r': 1089, 'c': 738}
# 962 595 1089 738
# ...
